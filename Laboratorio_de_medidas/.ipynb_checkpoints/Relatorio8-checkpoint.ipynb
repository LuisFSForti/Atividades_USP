# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f1 = [20, 60, 100, 400, 700, 1000, 1500, 2000, 2500, 5000, 10000]
vTeorico1 = [1, 0.998, 0.996, 0.938, 0.839, 0.734, 0.584, 0.475, 0.397, 0.211, 0.107]
vMedido1 = [0.968, 0.995, 0.99, 0.91, 0.85, 0.745, 0.594, 0.482, 0.402, 0.212, 0.103]
tTeorico1 = [-1.1, -3.2, -5.3, -20.3, -32.9, -42.8, -54.2, -61.6, -66.6, -77.8, -83.8]
tMedido1 = [-1.5, -3.7, -5.9, -20.5, -33.5, -43.4, -54.6, -61.9, -66.8, -77.7, -83.5]

f2 = [100, 500, 1000, 1500, 2500, 5000, 7500, 10000, 50000, 100000, 150000, 200000]
vTeorico2 = [0.999, 0.999, 0.996, 0.99, 0.973, 0.904, 0.816, 0.727, 0.207, 0.105, 0.07, 0.053]
vMedido2 = [0.98, 0.98, 0.98, 0.975, 0.96, 0.887, 0.802, 0.714, 0.22, 0.115, 0.073, 0.055]
tTeorico2 = [-0.5, -2.7, -5.4, -8.1, -13.2, -25.3, -35.3, -43.3, -78, -83.9, -86, -87]
tMedido2 = [-1.2, -3.3, -6, -8.3, -13.4, -24.8, -32, -42, -76.8, -82.4, -84.1, -84.9]

fig, ax = plt.subplots(2,2)
fig.set_figheight(15)
fig.set_figwidth(15)

ax[0,0].plot(f1, vTeorico1, "-r", label="V Teorico")
ax[0,0].plot(f1, vMedido1, "-b", label="V Medido")
ax[0,0].set_xscale("log")
ax[0,0].legend()
ax[0,0].title.set_text("f0 = 1,08 kHz")

ax[0,1].plot(f1, tTeorico1, "-r", label="θ Teorico")
ax[0,1].plot(f1, tMedido1, "-b", label="θ Medido")
ax[0,1].set_xscale("log")
ax[0,1].legend()
ax[0,1].title.set_text("f0 = 1,08 kHz")

ax[1,0].plot(f2, vTeorico2, "-r", label="V Teorico")
ax[1,0].plot(f2, vMedido2, "-b", label="V Medido")
ax[1,0].set_xscale("log")
ax[1,0].legend()
ax[1,0].title.set_text("f0 = 10,6 kHz")

ax[1,1].plot(f2, tTeorico2, "-r", label="θ Teorico")
ax[1,1].plot(f2, tMedido2, "-b", label="θ Medido")
ax[1,1].set_xscale("log")
ax[1,1].legend()
ax[1,1].title.set_text("f0 = 10,6 kHz")

plt.show()
