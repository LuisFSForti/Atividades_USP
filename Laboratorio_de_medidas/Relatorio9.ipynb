# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f1 = [100, 400, 700, 1000, 3000, 5000, 6000, 8000, 10000, 50000,100000,150000]
vTeorico1 = [0.1, 0.371, 0.572, 0.704, 0.909, 0.877, 0.846, 0.775, 0.704, 0.196, 0.1, 0.067]
vMedido1 = [0.089, 0.339, 0.519, 0.664, 0.862, 0.848, 0.823, 0.763, 0.7, 0.206, 0.102, 0.066]
tTeorico1 = [83.7, 65.9, 51, 39.3, 1.7, -15.2, -21.5, -31.5, -39.3, -77.5, -83.7, -85.8]
tMedido1 = [80.8, 64.1, 50.9, 40.1, 4.8, -11.5, -17.6, -27.2, -34.7, -75, -81.5, -83.3]

f2 = [100, 400, 700, 1e3, 2e3, 3e3, 4e3, 5e3, 10e3, 50e3, 100e3, 150e3]
vMedido2 = [0.963, 0.845, 0.674, 0.516, 0.207, 0.02, 0.129, 0.24, 0.579, 0.937, 0.978, 0.985]
tMedido2 = [-8.7, -30.2, -46.9, -58.9, -84.9, -160, 92.6, 81.5, 56, 14.6, 7.4, 4.5]

fig, ax = plt.subplots(2,2)
fig.set_figheight(15)
fig.set_figwidth(15)

ax[0,0].plot(f1, vTeorico1, "-r", label="V Teorico")
ax[0,0].plot(f1, vMedido1, "-b", label="V Medido")
ax[0,0].set_xscale("log")
ax[0,0].legend()
ax[0,0].title.set_text("Filtro passa-faixa (1 khZ - 10 kHz)")

ax[0,1].plot(f1, tTeorico1, "-r", label="θ Teorico")
ax[0,1].plot(f1, tMedido1, "-b", label="θ Medido")
ax[0,1].set_xscale("log")
ax[0,1].legend()
ax[0,1].title.set_text("Filtro passa-faixa (1 khZ - 10 kHz)")

ax[1,0].plot(f2, vMedido2, "-b", label="V Medido")
ax[1,0].set_xscale("log")
ax[1,0].legend()
ax[1,0].title.set_text("Filtro rejeita-faixa (3 kHz)")

ax[1,1].plot(f2, tMedido2, "-b", label="θ Medido")
ax[1,1].set_xscale("log")
ax[1,1].legend()
ax[1,1].title.set_text("Filtro rejeita-faixa (3 kHz)")

plt.show()
