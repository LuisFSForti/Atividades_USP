# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import math
import tabulate as tb

# %% [markdown]
# # Ex 1

# %% [markdown]
# https://www.ufrgs.br/reamat/CalculoNumerico/livro-oct/sdeduv-metodo_de_newton-raphson.html
#
# Para descobrir x* onde f(x*) = 0 de uma equação continuamente diferencíavel, pode-se calcular por meio da iteração do ponto fixo, onde x* é um ponto fixo da equação:
#
# g(x) = x + a(x) * f(x)
#
# Onde a(x) é uma função à ser definida <br>
# Derivando, temos:
#
# g'(x) = 1 + a'(x) * f(x) + a(x) * f'(x)
#
# Mas, como queremos f(x) = 0:
#
# g'(x) = 1 + a(x) * f'(x)
#
# Quanto menor for o g'(x), mais eficiente é a iteração, então, assumindo g'(x) = 0:
#
# 0 = 1 + a(x) * f'(x) <br>
# a(x) = -1/f'(x)
#
# Substituindo na primeira equação:
#
# g(x) = x - f(x)/f'(x) = x + δ
#
# Como, no ponto fixo, g(x*) = x*, então
#
# x* = x - f(x)/f'(x) = x + δ

# %% [markdown]
# # Ex 2

# %%
#Método para calcular a derivada de qualquer função unidimensional
def Derivada(x, funcao, dist):
    #Calcula a derivada da função pelo método da derivada finita central
    resC = (funcao(x + dist) - funcao(x - dist))/(2*dist)

    return resC

#Método iterativo do método de Newton
def MetodoDeNewton(x0, tol, max_it, r):
    k = 0
    err = 100
    x = x0
    while err > tol and k < max_it:
        #Chama a derivada da função, permitindo que qualquer função unidimensional possa ser calculada
        delta = -r(x)/Derivada(x, r, 1e-3)
        err = abs(delta)/abs(x)
        x = x + delta
        k += 1

    return x, k

# %%
#Função do exercício 2
def func(x):
    return np.cos(x) - x

#Derivada da função do exercício 2
#Esta foi utilizada para a função fsolve, à fim de testar o método iterativo
def DerivadaFunc(x):
    return -np.sin(x) - 1

x0 = 1
tol = 1e-6
max_it = 1e6

#Calcula pelo método iterativo programado
res1, k = MetodoDeNewton(x0, tol, max_it, func)
#Calcula pelo método fsolve, que será usado de referência
res2 = scipy.optimize.fsolve(func, x0, fprime = DerivadaFunc)

print("Iterações:", k, "\nResultado:", res1, "\nResultados por SciPy:", res2, "\nDiferença entre os resultados:", abs(res1-res2))
# Out:
# Iterações: 4
# Resultado: 0.7390851332151606
# Resultados por SciPy: [0.73908513]
# Diferença entre os resultados: [1.11022302e-16]

# %% [markdown]
# O método conseguiu, com pouquíssimas etapas, calcular o valor com uma precisão enorme <br>
# Desta forma, percebe-se como ele é eficiente e preciso, sendo muito útil para calcular a raiz de problemas não-lineares

# %% [markdown]
# # Ex 3

# %%
def PlotMetodoDeNewton(x0, tol, max_it, r):
    k = 0
    err = 100
    x = x0

    #Dados de cada iteração
    #Resultado da função no ponto
    R = []
    #Derivada no ponto
    Dvs = []
    #X atual
    X = []
    
    while err > tol and k < max_it:
        dv = Derivada(x, r, 1e-3)
        delta = -r(x)/dv

        #Salva os dados da iteração
        X.append(x)
        R.append(r(x))
        Dvs.append(dv)
        
        err = abs(delta)/abs(x)
        x = x + delta
        k += 1

    #Não salva os dados do último x, mas ele é muito próximo dos seus anteriores

    #Transforma os dados coletados para um array da classe do numpy
    X = np.array(X)
    R = np.array(R)
    Dvs = np.array(Dvs)

    #Para cada dado
    for i in range(len(Dvs) - 1):
        #Pega o ponto atual e o próximo
        xs = np.array(X[i:i+2])
        #Calcula uma reta, partindo do resultado do ponto inicial
        #indo até o próximo ponto, seguindo a derivada
        #Isto deve sair do ponto na função calculada até o y=0
        aux = Dvs[i] * (xs - xs[0]) + R[i]
        
        plt.plot(xs, aux, ":r")

    #Calcula a curva da função
    Xplot = np.linspace(min(X), max(X), 1000)
    Yplot = r(Xplot)
    plt.plot(Xplot, Yplot, "-b", label="f(x)")

    #Imprime os pontos obtidos
    plt.plot(X, R, "og", label="f(x)")

    #Imprime o eixo y=0, para facilitar a visualização
    plt.plot([min(Xplot), max(Xplot)], [0] * 2, ":m", label="Y = 0")
    #Imprime uma reta no x do ponto inicial, para facilitar a visualização
    plt.plot([x0]*2, [min(Yplot), max(Yplot)], ":k", label="X = X0 = " + str(x0))
    #Imprime uma reta no x do ponto obtido pelo método iterativo, para facilitar a visualização
    plt.plot([x]*2, [min(Yplot), max(Yplot)], ":c", label="X = " + str(x))
    
    plt.xlabel("x")
    plt.legend()
    plt.grid()
    plt.show()

    return x, k

x0 = 6
tol = 1e-10
max_it = 1e6

res1, k = PlotMetodoDeNewton(x0, tol, max_it, func)

print("Iterações:", k, "\nResultado:", res1)
# Out:
# Iterações: 10
# Resultado: 0.7390851332151606

# %% [markdown]
# Como pode-se ver no gráfico, quando a tangente do ponto intersecta com o y = 0, ela está no mesmo ponto (em x) que o próximo x calculado <br>
# Desta forma, é possível rastrear o passo-a-passo do método iterativo inteiro

# %% [markdown]
# # Ex 4

# %% [markdown]
# ## 4.1 Código de cálculo do sistema

# %%
def Assembly(conec, C):
    #Procura o maior valor entre o maior valor de cada coluna, assim encontrando o tamanho
    #Soma-se 1 porque, se o maior nó é o 72, então ele precisa de 73 espaços (pois o primeiro é o 0)
    nv = max([max(conec[:,0]), max(conec[:,1])]) + 1
    #Quantidade de canos = número de ligações = tamanho da lista de Condutâncias
    nc = len(C)
    A = np.zeros(shape=(nv,nv))
    #Para cada cano
    for k in range(nc):
        #Pega os nós conectados
        n1 = conec[k, 0]
        n2 = conec[k, 1]

        #Salva na matriz A os valores da condutância do cano de acordo com os nós respectivos
        A[n1, n1] += C[k]
        A[n1, n2] += -C[k]
        A[n2, n1] += -C[k]
        A[n2, n2] += C[k]

    return A

#Para calcular as pressões de cada nó e vazões de cada cano
def SolveNetwork(conec, C, natm, nB, QB, imprimir):
    #Procura o maior valor entre o maior valor de cada coluna, assim encontrando o tamanho
    nv = max([max(conec[:,0]), max(conec[:,1])]) + 1

    #Pega a matriz A
    Atilde = Assembly(conec, C)
    #Altera a linha do nó de saída da massa
    Atilde[natm, :] = 0
    Atilde[natm, natm] = 1

    #Cria a matriz de variação da massa
    b = np.zeros(shape=nv)
    #Salva em qual nó está entrando massa externa
    b[nB] = QB

    #Resolve a matriz, assumindo Ã como dados, b como resultados e calculando o vetor de pressões intermediário
    pressure = np.linalg.solve(Atilde, b)

    #Para não desacelerar desnecessariamente o último exercício
    if imprimir:
        print("Ã = ", Atilde, "\n\nb = ", b, "\n\nPressão = ", pressure)
    return pressure

def CalcularPotencia(p, D, K):
    pT = np.transpose(p)
    Dt = np.transpose(D)
    aux = Dt.dot(K).dot(D)
    W = pT.dot(aux).dot(p)
    return W

def GeraRede(nx,ny, CH, CV):
    nv = nx*ny
    nc = (nx-1)*ny + (ny-1)*nx
    
    coord = np.zeros(shape=(nv,2))

    for i in range(nx):
        for j in range(ny):
            ig = i + j*nx
            coord[ig,0] = i
            coord[ig,1] = j

    conec = np.zeros(shape=(nc,2), dtype=int)
    C = np.zeros(nc)
    
    # Loop sobre canos horizontais
    for j in range(ny):
        for i in range(nx-1):
            k = j*(nx-1) + i
            conec[k,0] = j*nx + i
            conec[k,1] = j*nx + i+1
            C[k] = CH
            

    # Loop sobre canos verticais
    for i in range(nx):
        for j in range(ny-1):
            k = (nx-1)*ny + j*nx + i
            conec[k,0] = i + j*nx
            conec[k,1] = i + (j+1)*nx
            C[k] = CV

    return nv, nc, conec, C, coord

def PlotPressure(nx, ny, pressure):
    x = np.arange(0, nx, 1)
    y = np.arange(0, ny, 1)
    X,Y=np.meshgrid(x,y)
    Z = np.copy(pressure)
    Z.shape = (ny,nx)
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_aspect('equal')
    ax.set(xlabel='x', ylabel='y', title='Contours of pressure')
    ax.grid()
    ax.set_xticks(x)
    ax.set_yticks(y)
    cp = plt.contourf(X, Y, Z, cmap='jet')
    cb = plt.colorbar(cp)
    plt.show()

def PlotPressureAsSurface(nx, ny, pressure):
    x = np.arange(0, nx, 1)
    y = np.arange(0, ny, 1)
    X,Y=np.meshgrid(x,y)
    Z = np.copy(pressure)
    Z.shape = (ny,nx)
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_aspect('equal')
    ax.set(xlabel='x', ylabel='y', title='Contours of pressure')
    ax.grid()
    ax.set_xticks(x)
    ax.set_yticks(y)
    ax = plt.axes(projection="3d")
    ax.plot_surface(X, Y, Z, cmap='jet', edgecolor=None)
    ax.set(xlabel='$x$', ylabel='$y$', zlabel='$z$')
    ax.view_init(elev=30., azim=45)
    plt.show()

def FormarK(C):
    nc = len(C)
    K = np.zeros(shape=(nc,nc))
    #Salva o valor de cada condutância de acordo com o cano relacionado
    for k in range(nc):
        K[k, k] = C[k]

    return K

#Calcular a matrix de fluxo
def FormarD(conec, C):
    #Procura o maior valor entre o maior valor de cada coluna, assim encontrando o tamanho
    nv = max([max(conec[:,0]), max(conec[:,1])]) + 1
    nc = len(C)

    #Como a matriz define quais nós são a entrada e saída de cada cano,
    #ela possui uma linha pra cada cano, uma coluna pra cada nó
    D = np.zeros(shape=(nc,nv))
    for k in range(nc):
        #Pega os nós do cano
        n1 = conec[k, 0]
        n2 = conec[k, 1]

        D[k,n1] = 1
        D[k,n2] = -1

    return D

# %% [markdown]
# ## 4.2 Código utilizado pelo método iterativo

# %%
#Método para calcular a potência no ponto x
def Potencia(x):
    n, m = 9, 8
    QB = 3
    nAtm = n*m - 1
    nB = 0
    
    CH = 2.3 + 10*pow(math.e, -pow(x - 5, 2))
    CV = 1.8 + 10*pow(math.e, -pow(x - 5, 2))
    
    nv, nc, conec, C, coord = GeraRede(n, m, CH, CV)
    
    p = SolveNetwork(conec, C, nAtm, nB, QB, False)
    
    K = FormarK(C)
    D = FormarD(conec, C)
    
    pT = np.transpose(p)
    Dt = np.transpose(D)
    aux = Dt.dot(K).dot(D)
    W = pT.dot(aux).dot(p)
        
    return W

#Método para desenhar a potência em função de x
def ShowPotencia(res1, res2):
    div = np.linspace(1, 10, 100)
    aux = []
    for x in div:
        aux.append(Potencia(x))

    #Plot da potência
    plt.plot(div, aux, "-m")

    #Plot dos resultados
    plt.plot([res1] * 2, [min(aux), max(aux)], ":r", label="X = " + str(res1))
    plt.plot([res2] * 2, [min(aux), max(aux)], ":b", label="X = " + str(res2))
    plt.plot([min(div), max(div)], [12] * 2, ":g", label="P = 12")

    plt.legend()
    plt.title("Potencia")
    plt.show()

# %%
#Função utilizada pelo exercício 4
def func2(x):
    return Potencia(x) - 12

tol = 1e-10
max_it = 1e4

#Esta função possui duas respostas
#Para calcular a primeira
x0 = 4
res1, k1 = MetodoDeNewton(x0, tol, max_it, func2)

#Para calcular a segunda
x0 = 6
res2, k2 = MetodoDeNewton(x0, tol, max_it, func2)

ShowPotencia(res1, res2)

print("Iterações: ", k1, " - Resultado: ", res1, " - Potencia em ", res1, ": ", Potencia(res1), sep="")
print("Iterações: ", k2, " - Resultado: ", res2, " - Potencia em ", res2, ": ", Potencia(res2), sep="")
# Out:
# Iterações: 6 - Resultado: 2.757839541005873 - Potencia em 2.757839541005873: 12.000000000000043
# Iterações: 6 - Resultado: 7.242160458994017 - Potencia em 7.242160458994017: 11.999999999999567

# %% [markdown]
# Como pode-se perceber no gráfico, ele conseguiu realizar a operação e conseguiu resultados precisos <br>
# Neste exercício ele também demonstrou que, para uma mesma função, podem existir múltiplas raízes, as quais só serão descobertar alterando o valor inicial <br>
# No entanto, ele também apresentou que seu potencial depende muito do valor inicial, pois mudanças no valor inicial resultaram em operações desnecessariamente longas ou simplesmente não foi capaz de fazer <br>
# Isto pode ser explicado pela visualização geométrica do método: quando o x é menor que 2, está entre 4.15 e 5.85, ou é maior que 8, as derivadas nos pontos acabam muito próximas de 0 e, portanto,  acabam por levar o próximo ponto longe demais do resultado, impedindo que o cálculo seja feito adequadamente <br>
# Assim, ele se mostra como um método eficiente, no entanto extremamente volátil
