# %% [markdown]
# ## Luís Forti - 3981932
# ## Marcell Slyuch - 3992616

# %% [markdown]
# # CV - Image Classification Lab
#
# Note that this lab has three levels: basic, regular and advanced.
#
#
# Doing the **basic** part earns you a grade of 5.5-6.0.
#
# Doing the **regular** part earns you a max grade of 8.0.
#
# Doing the **advanced** part earns you a max grade of 10.0.
#
# Please return a Jupyter notebook as a submission in Canvas, this makes grading easier for us.
#
# <font color="red" size="4" face="Arial">As you go through the exercises, you'll encounter various example outputs. Use these as references while navigating the assignment. However, matching these exact values or neural network structures isn't the primary objective. You're encouraged to adjust the parameters as needed, ensuring they remain relevant and appropriate for the task at hand.</font>

# %% [markdown]
# ## Basic Level
# In this part, we will attempt a binary classification problem using a DNN and a CNN.
#
# We will then proceed to change our network architectures to solve a multiclassification problem.
#
# The dataset used consists of medical images of breast cancer using ultrasound scan.
#
# The images are categorized into three classes, which are **normal**, **benign**, and **malignant**.
#
# ### Necessary imports

# %%
import pandas as pd
import numpy as np
from PIL import Image
import os
import os.path
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
from matplotlib import pyplot as plt
import keras
from keras.utils import to_categorical 
import random
from sklearn.metrics import confusion_matrix
from scipy.special import softmax
from keras.layers import LeakyReLU
from sklearn.utils import shuffle
from keras.layers import  Input, Dense, BatchNormalization, Conv2D
from keras import layers
from keras.layers import Input, Dense, Activation,BatchNormalization, Flatten, Conv2D, MaxPooling2D
from keras.models import Model
from keras.preprocessing import image
import keras.backend as K
# Out:
# WARNING:tensorflow:From C:\Users\luis\venvs\ml_env\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
folder = 'Assignment_Dataset'
rs=1
ts=0.25

# %% [markdown]
# ### Exercise 1
# The directory above contains the dataset for this week's assignment.
#
# You'll find three folders within it, **normal** ,**malignant** and **benign**.
# Load the images within the three folders, with the appropriate labels (the images within the folder **malignant** should be labelled with **malignant**, same goes for **benign** and **normal**).
# One way to do this, is to load the images in one list, and load the labels (corresponding to the name of the folder you load the scans from) in another list.
#
# Note also that we're working with a small dataset.

# %%
images = []
labels = []

for label in ['normal', 'malignant', 'benign']:
    path = os.path.join(folder, label)

    for filename in tqdm(os.listdir(path), desc=label):
        filepath = os.path.join(path, filename)

        try:
            img = Image.open(filepath)
            images.append(img)
            labels.append(label)
        except:
            pass
# Out:
# normal: 100%|██████████| 133/133 [00:00<00:00, 8048.75it/s]
# malignant: 100%|██████████| 210/210 [00:00<00:00, 7503.99it/s]
# benign: 100%|██████████| 437/437 [00:00<00:00, 8755.46it/s]

# %%
print("In all folders, we have", len(images),"images","and ", len(labels), "corresponding labels")
print(pd.Series(labels).value_counts())
# Out:
# In all folders, we have 780 images and  780 corresponding labels
# benign       437
# malignant    210
# normal       133
# Name: count, dtype: int64

# %%
vis_images, vis_label = shuffle(images, labels)
plt.figure(figsize=(10, 10))
for i in range(1, 10):  
    plt.subplot(3, 3, i)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    plt.imshow(vis_images[i-1])
    plt.title(f'Label: {vis_label[i-1]}', fontsize=12)
    width, height = vis_images[i-1].size
    plt.xlabel(f'Width: {width}', fontsize=10)
    plt.ylabel(f'Height: {height}', fontsize=10)
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# ### Exercise 2
# Write a function **convert(dataset, target_mode)** that will take your list of images and convert them from their current mode RGB, to the target mode **L** (grayscale)

# %%
print("The current mode of the images in the dataset is",images[0].mode)
# Out:
# The current mode of the images in the dataset is RGB

# %%
def convert(dataset, mode): 
    converted = []

    for img in tqdm(dataset):
        converted.append(img.convert(mode))
    return converted

# %%
images=convert(images, 'L')
# Out:
# 100%|██████████| 780/780 [00:04<00:00, 182.95it/s]

# %%
print("Image mode is now",images[0].mode)
# Out:
# Image mode is now L

# %% [markdown]
# ### Exercise 3
# It turns out that the images in our dataset are not of the same size.
# Write a function **check_size(dataset)**, which inputs your dataset of images and returns True if all images are of the same size and False otherwise.

# %%
def check_size(dataset):
    first_size = dataset[0].size

    for img in dataset:
        if img.size != first_size:
            return False
    return True

# %%
print("All images are of the same size:",check_size(images))
# Out:
# All images are of the same size: False

# %% [markdown]
# ### Exercise 4
# Write a function **resize(dataset, size)**, to which you pass your dataset and a tuple (h, w). Your function should output the dataset with all the images in the same size.

# %%
def resize(dataset, size):
    resized = []

    for img in tqdm(dataset):
        resized.append(img.resize((size[1], size[0])))

    return resized

# %%
resized_images=resize(images, (64,64))
# Out:
# 100%|██████████| 780/780 [00:00<00:00, 2531.32it/s]

# %%
print("All images are of the same size:",check_size(resized_images))
# Out:
# All images are of the same size: True

# %%
print(type(images[0]))
# Out:
# <class 'PIL.Image.Image'>

# %% [markdown]
# ### Exercise 5
# Recall that a model cannot be trained on an Image object, we need first to convert our dataset of images into a dataset of numpy arrays, in which every array is the representation of an image.
#
# Write a function **to_npArray(dataset)**, which will input your images dataset and return the dataset with the images converted to numpy arrays.

# %%
def to_npArray(dataset):
    np_dataset = []

    for img in tqdm(dataset):
        np_dataset.append(np.array(img))

    return np_dataset

# %%
np_images=to_npArray(resized_images)
# Out:
# 100%|██████████| 780/780 [00:00<00:00, 80546.50it/s]

# %%
np_images=np.array(np_images)

# %%
np_images.shape
# Out:
# (780, 64, 64)

# %% [markdown]
# #### You can see now that our dataset has 780 examples, each example is of the shape (h,w). In our case here (64,64). Feel free to resize your images to the values you see fit. Keep in mind that a higher size means more features, slower training, and a risk of overfitting.

# %% [markdown]
# ### Exercise 6
# Pixel values in our grayscale images might go up to 255, when calculating sigmoid of such values (multiplied by their respective weights), we might end up with overflow issues.
# One way to solve this problem is by feature scaling.
# You can use sklearn's [MixMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html) to scale the features in your dataset. You can also implement your own scaler, by simply dividing all the values in your dataset by the max value.

# %%
def scale(dataset):
    return np.array(dataset) / 255.0

# %%
np_images = scale(np_images)
print(np_images[0])
# Out:
# [[0.38823529 0.34117647 0.69019608 ... 0.70196078 0.70980392 0.66666667]
#  [0.3372549  0.41960784 0.65882353 ... 0.71764706 0.78823529 0.7372549 ]
#  [0.39215686 0.5254902  0.59607843 ... 0.87843137 0.77647059 0.62745098]
#  ...
#  [0.08235294 0.06666667 0.08235294 ... 0.08235294 0.08627451 0.09019608]
#  [0.07843137 0.07058824 0.0745098  ... 0.08627451 0.08627451 0.09019608]
#  [0.07843137 0.07843137 0.09019608 ... 0.09019608 0.07843137 0.08235294]]

# %% [markdown]
# ## Binary classification
# We'll start by doing a binary classification problem.
#
# In later exercises, we will shift back to treating the multiclassification problem the dataset suggests.
# ### Exercise 7
#
# We are now preparing our dataset for binary classification. While our dataset contains three classes - **benign**, **malignant**, and **normal** - our initial model will categorize the scans as either **0** (malignant) or **1** (either normal or benign). We'll formulate a 'y' vector where the '**malignant**' label is encoded as **0**, and the other labels are encoded as **1**.

# %%
def binary_labels(labels):
    y = []

    for label in tqdm(labels):
        if label == 'malignant':
            y.append(0)
        else:
            y.append(1)

    return np.array(y)

# %%
y = binary_labels(labels)
print(y.shape)
# Out:
# 100%|██████████| 780/780 [00:00<00:00, 519872.42it/s]
# (780,)

# %% [markdown]
# ### Exercise 8
#
# For this task, you'll employ **Keras** to construct your neural network. We've shown in the lecture how straightforward it is to design DNNs with Keras: all you need to do is outline your network's structure and let Keras do the heavy lifting.
#
# The lecture's demonstration assumes that images have been flattened before they are fed into the Keras DNN. This means the dataset will have a shape like (ne, w, h). Given our dataset with **780 samples** and an image size of (64 , 64), when you flatten these images, they will reshape the dataset to (780, 4096).
#
# Keras can also handle the flattening for you. So, you can supply the dataset in the shape (780, 64, 64) and Keras will take care of reshaping before starting the model's training.
#
# a. Reshape your dataset to what Keras expects

# %%
def reshape_dataset(dataset):
    return np.array(dataset).reshape(len(dataset), -1)

# %%
np_images_flattened = reshape_dataset(np_images)
np_images_flattened.shape
# Out:
# (780, 4096)

# %%
train_X, test_X, train_y, test_y = train_test_split(np_images_flattened, y, test_size=ts, shuffle=True, random_state=rs)

# %% [markdown]
# b. Create your model and compile it in the cell below

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(train_X.shape[1],)),
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(64, activation='sigmoid'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.00001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From C:\Users\luis\venvs\ml_env\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1090049 (4.16 MB)
# Trainable params: 1090049 (4.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# c. Fit the model to the data below

# %%
history = model.fit(
    train_X,
    train_y,
    validation_data=(test_X, test_y),
    epochs=250,
    batch_size=32
)
# Out:
# Epoch 1/250
# WARNING:tensorflow:From C:\Users\luis\venvs\ml_env\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\luis\venvs\ml_env\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 19/19 [==============================] - 1s 17ms/step - loss: 0.6303 - accuracy: 0.7231 - val_loss: 0.6077 - val_accuracy: 0.7538
# Epoch 2/250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6155 - accuracy: 0.7231 - val_loss: 0.5912 - val_accuracy: 0.7538
# Epoch 3/250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6047 - accuracy: 0.7231 - val_loss: 0.5812 - val_accuracy: 0.7538
# Epoch 4/250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.5987 - accuracy: 0.7231 - val_loss: 0.5741 - val_accuracy: 0.7538
# Epoch 5/250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.5943 - accuracy: 0.7231 - val_loss: 0.5695 - val_accuracy: 0.7538
# Epoch 6/250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.5920 - accuracy: 0.7231 - val_loss: 0.5655 - val_accuracy: 0.7538
# Epoch 7/250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.
250
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3995 - accuracy: 0.8325 - val_loss: 0.4414 - val_accuracy: 0.8154

# %%
# visualise training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc="lower right")
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# d. Print the accuracy of your model on the train and test set

# %%
train_loss, train_accuracy = model.evaluate(train_X, train_y, verbose=0)
test_loss, test_accuracy = model.evaluate(test_X, test_y, verbose=0)

print(f"Train accuracy: {train_accuracy * 100:.2f}%")
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Train accuracy: 83.25%
# Test accuracy: 81.54%

# %% [markdown]
# e. Update (by simply rerunning the cell) the confusion matrix below to check how good your model has done on the data.

# %%
predictions = model.predict(test_X)
predicted_labels = (predictions > 0.5).astype("int32")
cm = confusion_matrix(test_y, predicted_labels)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# ### Exercise 9
# Let's now try the same thing with a CNN and see whether we can improve on the results we get.
# You're free to try any CNN architecture you wish. Keep in mind that a high number of layers and of filters in these layers makes the number of parameters grow, and makes the learning duration longer.

# %%
train_X, test_X, train_y, test_y = train_test_split(np_images, y, test_size=ts, shuffle=True, random_state=rs)

# %% [markdown]
# a. Create and compile your model architecture below

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(64, 64, 1)),

    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.00001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From C:\Users\luis\venvs\ml_env\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 128)               589952
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 682753 (2.60 MB)
# Trainable params: 682753 (2.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# b. Fit your CNN to the data

# %%
history = model.fit(
    train_X,
    train_y,
    validation_data=(test_X, test_y),
    epochs=250,
    batch_size=32
)
# Out:
# Epoch 1/250
# 19/19 [==============================] - 2s 38ms/step - loss: 0.6811 - accuracy: 0.5949 - val_loss: 0.6545 - val_accuracy: 0.7538
# Epoch 2/250
# 19/19 [==============================] - 1s 30ms/step - loss: 0.6444 - accuracy: 0.7265 - val_loss: 0.6171 - val_accuracy: 0.7538
# Epoch 3/250
# 19/19 [==============================] - 1s 30ms/step - loss: 0.6170 - accuracy: 0.7231 - val_loss: 0.5912 - val_accuracy: 0.7538
# Epoch 4/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.6011 - accuracy: 0.7231 - val_loss: 0.5708 - val_accuracy: 0.7538
# Epoch 5/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5854 - accuracy: 0.7231 - val_loss: 0.5562 - val_accuracy: 0.7538
# Epoch 6/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5783 - accuracy: 0.7231 - val_loss: 0.5476 - val_accuracy: 0.7538
# Epoch 7/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5731 - accuracy: 0.7231 - val_loss: 0.5423 - val_accuracy: 0.7538
# Epoch 8/250
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5705 - accuracy: 0.7231 - val_loss: 0.5390 - val_accuracy: 0.7538
# Epoch 9/250
# 19/19 [==============================] - 1s 39ms/step - loss: 0.5644 - accuracy: 0.7231 - val_loss: 0.5382 - val_accuracy: 0.7538
# Epoch 10/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0
250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.3530 - accuracy: 0.8598 - val_loss: 0.4211 - val_accuracy: 0.8308
# Epoch 238/250
# 19/19 [==============================] - 1s 35ms/step - loss: 0.3515 - accuracy: 0.8650 - val_loss: 0.4202 - val_accuracy: 0.8308
# Epoch 239/250
# 19/19 [==============================] - 1s 34ms/step - loss: 0.3543 - accuracy: 0.8513 - val_loss: 0.4230 - val_accuracy: 0.8256
# Epoch 240/250
# 19/19 [==============================] - 1s 36ms/step - loss: 0.3543 - accuracy: 0.8615 - val_loss: 0.4207 - val_accuracy: 0.8308
# Epoch 241/250
# 19/19 [==============================] - 1s 58ms/step - loss: 0.3461 - accuracy: 0.8598 - val_loss: 0.4205 - val_accuracy: 0.8308
# Epoch 242/250
# 19/19 [==============================] - 1s 32ms/step - loss: 0.3525 - accuracy: 0.8598 - val_loss: 0.4225 - val_accuracy: 0.8256
# Epoch 243/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3487 - accuracy: 0.8547 - val_loss: 0.4202 - val_accuracy: 0.8256
# Epoch 244/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3548 - accuracy: 0.8581 - val_loss: 0.4212 - val_accuracy: 0.8308
# Epoch 245/250
# 19/19 [==============================] - 1s 34ms/step - loss: 0.3481 - accuracy: 0.8598 - val_loss: 0.4201 - val_accuracy: 0.8205
# Epoch 246/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3449 - accuracy: 0.8598 - val_loss: 0.4206 - val_accuracy: 0.8308
# Epoch 247/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3444 - accuracy: 0.8615 - val_loss: 0.4206 - val_accuracy: 0.8308
# Epoch 248/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3424 - accuracy: 0.8632 - val_loss: 0.4204 - val_accuracy: 0.8308
# Epoch 249/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3469 - accuracy: 0.8598 - val_loss: 0.4227 - val_accuracy: 0.8256
# Epoch 250/250
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3543 - accuracy: 0.8615 - val_loss: 0.4196 - val_accuracy: 0.8308

# %%
# visualise training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0, 1)
plt.legend(['train', 'test'], loc="lower right")
plt.show()

# %% [markdown]
# c. Print your model's accuracy on the test and train sets

# %%
train_loss, train_accuracy = model.evaluate(train_X, train_y, verbose=0)
test_loss, test_accuracy = model.evaluate(test_X, test_y, verbose=0)

print(f"Train accuracy: {train_accuracy * 100:.2f}%")
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Train accuracy: 86.15%
# Test accuracy: 83.08%

# %% [markdown]
# d. Create a confusion matrix to inspect the model's output

# %%
predictions = model.predict(test_X)
predicted_labels = (predictions > 0.5).astype("int32")
cm = confusion_matrix(test_y, predicted_labels)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 7/7 [==============================] - 0s 8ms/step

# %% [markdown]
# Turns out my CNN architecture underperforms against my DNN. Depending on how your CNNs architecture and parameters are, you might get better results.

# %% [markdown]
# ## Multiclassification
# Let's now shift back to building models that can distinguish the three classes, and not just segregate the **normal** scans from the other scans.
#
# Our first task is to encode our **y** vector properly.
# Keep also in mind that the **sigmoid** activation is not the right choice for the output layer, and that the number of neurons of the output layer needs to be equal to the number of expected classes.
#
# ### Exercise 10
# Create a **y** matrix for your labels. The **y** matrix is of shape **(ne, nc)**.
#
# With **ne** meaning number of examples and **nc** meaning number of possible classes.
#
# Refer to keras' to_categorical() function to create your ground truth matrix.

# %%
y = to_categorical(
    [0 if label == 'malignant' else 1 if label == 'benign' else 2 for label in labels],
    num_classes=3
)

# %%
y.shape
# Out:
# (780, 3)

# %% [markdown]
# ### Exercise 11

# %%
train_X, test_X, train_y, test_y = train_test_split(np_images_flattened, y, test_size=ts, shuffle=True, random_state=rs)

# %% [markdown]
# a. You can now create another DNN to classify your scans according to their labels.

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(train_X.shape[1],)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.05),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.05),
    keras.layers.Dense(3, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 128)               524416
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 533379 (2.03 MB)
# Trainable params: 533123 (2.03 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# b. Train your model below

# %%
history = model.fit(
    train_X,
    train_y,
    validation_data=(test_X, test_y),
    epochs=250,
    batch_size=32
)
# Out:
# Epoch 1/250
# 19/19 [==============================] - 1s 15ms/step - loss: 1.1075 - accuracy: 0.4154 - val_loss: 1.0511 - val_accuracy: 0.4821
# Epoch 2/250
# 19/19 [==============================] - 0s 7ms/step - loss: 1.0012 - accuracy: 0.5009 - val_loss: 1.0384 - val_accuracy: 0.5231
# Epoch 3/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.9309 - accuracy: 0.5607 - val_loss: 1.0252 - val_accuracy: 0.5487
# Epoch 4/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.9054 - accuracy: 0.5761 - val_loss: 1.0150 - val_accuracy: 0.5590
# Epoch 5/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8795 - accuracy: 0.6085 - val_loss: 1.0059 - val_accuracy: 0.5744
# Epoch 6/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8236 - accuracy: 0.6308 - val_loss: 0.9958 - val_accuracy: 0.6000
# Epoch 7/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8305 - accuracy: 0.6376 - val_loss: 0.9873 - val_accuracy: 0.6000
# Epoch 8/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8107 - accuracy: 0.6615 - val_loss: 0.9734 - val_accuracy: 0.6000
# Epoch 9/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7986 - accuracy: 0.6752 - val_loss: 0.9553 - val_accuracy: 0.6000
# Epoch 10/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7663 - accuracy: 0.7077 - val_loss: 0.9441 - val_accuracy: 0.6154
# Epoch 11/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7578 - accuracy: 0.7128 - val_loss: 0.9361 - val_accuracy: 0.6154
# Epoch 12/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7287 - accuracy: 0.7316 - val_loss: 0.9209 - val_accuracy: 0.6154
# Epoch 13/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7059 - accuracy: 0.7538 - val_loss: 0.9114 - val_accuracy: 0.6103
# Epoch 14/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7085 - accuracy: 0.7402 - val_loss: 0.8961 - val_accuracy: 0.6154
# Epoch 15/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6800 - accuracy: 0.7590 - val_loss: 0.8876 - val_accuracy: 0.6205
# Epoch 16/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6833 - accuracy: 0.7350 - val_loss: 0.8807 - val_accuracy: 0.6205
# Epoch 17/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6681 - accuracy: 0.7521 - val_loss: 0.8722 - val_accuracy: 0.6205
# Epoch 18/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6554 - accuracy: 0.7538 - val_loss: 0.8571 - val_accuracy: 0.6308
# Epoch 19/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6485 - accuracy: 0.7658 - val_loss: 0.8571 - val_accuracy: 0.6410
# Epoch 20/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6474 - accuracy: 0.7607 - val_loss: 0.8495 - val_accuracy: 0.6359
# Epoch 21/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6319 - accuracy: 0.7538 - val_loss: 0.8377 - val_accuracy: 0.6410
# Epoch 22/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.
250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9966 - val_loss: 0.8065 - val_accuracy: 0.7231
# Epoch 238/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.9949 - val_loss: 0.8084 - val_accuracy: 0.7077
# Epoch 239/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0688 - accuracy: 0.9966 - val_loss: 0.8259 - val_accuracy: 0.7026
# Epoch 240/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0686 - accuracy: 0.9932 - val_loss: 0.8324 - val_accuracy: 0.7026
# Epoch 241/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0684 - accuracy: 0.9949 - val_loss: 0.8205 - val_accuracy: 0.7231
# Epoch 242/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.8166 - val_accuracy: 0.7231
# Epoch 243/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0650 - accuracy: 0.9966 - val_loss: 0.8266 - val_accuracy: 0.7026
# Epoch 244/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0685 - accuracy: 0.9949 - val_loss: 0.8282 - val_accuracy: 0.7179
# Epoch 245/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0626 - accuracy: 0.9966 - val_loss: 0.8201 - val_accuracy: 0.7179
# Epoch 246/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0626 - accuracy: 0.9983 - val_loss: 0.8461 - val_accuracy: 0.6974
# Epoch 247/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0694 - accuracy: 0.9949 - val_loss: 0.8397 - val_accuracy: 0.7077
# Epoch 248/250
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0670 - accuracy: 0.9966 - val_loss: 0.8278 - val_accuracy: 0.7026
# Epoch 249/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0643 - accuracy: 0.9966 - val_loss: 0.8211 - val_accuracy: 0.7231
# Epoch 250/250
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0643 - accuracy: 0.9949 - val_loss: 0.8406 - val_accuracy: 0.7077

# %%
# visualise training history
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0,1)
plt.legend(['train', 'test'], loc="lower right")
plt.show()

# %% [markdown]
# The use of the dropout layers did not prevent the model from memorizing the data.
#
# The network architecture I used is complex and the training dataset is too small.

# %% [markdown]
# c. Print your model's accuracy on the test and train sets

# %%
train_loss, train_accuracy = model.evaluate(train_X, train_y, verbose=0)
test_loss, test_accuracy = model.evaluate(test_X, test_y, verbose=0)

print(f"Train accuracy: {train_accuracy * 100:.2f}%")
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Train accuracy: 99.83%
# Test accuracy: 70.77%

# %% [markdown]
# d. Create a confusion matrix to inspect the model's output

# %%
predictions = model.predict(test_X)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_y, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='g',
    xticklabels=['Malignant', 'Benign', 'Normal'],
    yticklabels=['Malignant', 'Benign', 'Normal']
)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('DNN Confusion Matrix')
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# ### Exercise 12
# Use Keras again to build and train a new CNN to classify the scans into three the three classes.

# %%
train_X, test_X, train_y, test_y = train_test_split(np_images, y, test_size=ts, shuffle=True, random_state=rs)

# %% [markdown]
# a. Create your CNN's architecture and compile it

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(64, 64, 1)),

    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 62, 62, 32)        320
#
#  batch_normalization_1 (Bat  (None, 62, 62, 32)        128
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 31, 31, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 29, 29, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 29, 29, 64)        256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_3 (Bat  (None, 12, 12, 128)       512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 4608)              0
#
#  dense_9 (Dense)             (None, 128)               589952
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 683907 (2.61 MB)
# Trainable params: 683459 (2.61 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %% [markdown]
# b. Fit your model to the data

# %%
history = model.fit(
    train_X,
    train_y,
    validation_data=(test_X, test_y),
    epochs=250,
    batch_size=32
)
# Out:
# Epoch 1/250
# 19/19 [==============================] - 2s 50ms/step - loss: 1.6923 - accuracy: 0.4974 - val_loss: 1.3170 - val_accuracy: 0.2462
# Epoch 2/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.8579 - accuracy: 0.6291 - val_loss: 1.7573 - val_accuracy: 0.2462
# Epoch 3/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.6570 - accuracy: 0.7145 - val_loss: 2.1768 - val_accuracy: 0.2462
# Epoch 4/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.5459 - accuracy: 0.7744 - val_loss: 2.5202 - val_accuracy: 0.2462
# Epoch 5/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.4470 - accuracy: 0.8085 - val_loss: 2.7314 - val_accuracy: 0.2462
# Epoch 6/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.3914 - accuracy: 0.8496 - val_loss: 3.2435 - val_accuracy: 0.2462
# Epoch 7/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.3265 - accuracy: 0.8735 - val_loss: 3.2402 - val_accuracy: 0.2462
# Epoch 8/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.2805 - accuracy: 0.9009 - val_loss: 3.7311 - val_accuracy: 0.2462
# Epoch 9/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.2409 - accuracy: 0.9248 - val_loss: 3.9010 - val_accuracy: 0.2462
# Epoch 10/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2342 - accuracy: 0.9162 - val_loss: 4.0557 - val_accuracy: 0.2462
# Epoch 11/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1795 - accuracy: 0.9436 - val_loss: 4.0714 - val_accuracy: 0.2462
# Epoch 12/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1591 - accuracy: 0.9538 - val_loss: 4.2709 - val_accuracy: 0.2462
# Epoch 13/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1295 - accuracy: 0.9709 - val_loss: 4.2624 - val_accuracy: 0.2462
# Epoch 14/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1168 - accuracy: 0.9744 - val_loss: 4.2966 - val_accuracy: 0.2462
# Epoch 15/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.1109 - accuracy: 0.9761 - val_loss: 4.4998 - val_accuracy: 0.2462
# Epoch 16/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0928 - accuracy: 0.9812 - val_loss: 4.5464 - val_accuracy: 0.2462
# Epoch 17/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0843 - accuracy: 0.9812 - val_loss: 4.6447 - val_accuracy: 0.2462
# Epoch 18/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0929 - accuracy: 0.9744 - val_loss: 4.4611 - val_accuracy: 0.2462
# Epoch 19/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0890 - accuracy: 0.9726 - val_loss: 4.0750 - val_accuracy: 0.2462
# Epoch 20/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0732 - accuracy: 0.9897 - val_loss: 3.4878 - val_accuracy: 0.2462
# Epoch 21/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0660 - accuracy: 0.9949 - val_loss: 3.4302 - val_accuracy: 0.2462
# Epoch 22/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0805 - accuracy: 0.9778 - val_loss: 3.3256 - val_accuracy: 0.2462
# Epoch 23/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0498 - accuracy: 0.9949 - val_loss: 3.1545 - val_accuracy: 0.2462
# Epoch 24/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0469 - accuracy: 0.9880 - val_loss: 3.0655 - val_accuracy: 0.2564
# Epoch 25/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0568 - accuracy: 0.9863 - val_loss: 2.9964 - val_accuracy: 0.2615
# Epoch 26/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0444 - accuracy: 0.9880 - val_loss: 2.6997 - val_accuracy: 0.2769
# Epoch 27/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0466 - accuracy: 0.9897 - val_loss: 2.4713 - val_accuracy: 0.3026
# Epoch 28/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0402 - accuracy: 0.9932 - val_loss: 2.2593 - val_accuracy: 0.3333
# Epoch 29/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0321 - accuracy: 0.9915 - val_loss: 1.8001 - val_accuracy: 0.4051
# Epoch 30/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0415 - accuracy: 0.9915 - val_loss: 1.5053 - val_accuracy: 0.4667
# Epoch 31/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0404 - accuracy: 0.9897 - val_loss: 1.3556 - val_accuracy: 0.5231
# Epoch 32/250
# 19/19 [==============================] - 1s 52ms/step - loss: 0.0419 - accuracy: 0.9897 - val_loss: 1.2730 - val_accuracy: 0.5641
# Epoch 33/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0323 - accuracy: 0.9915 - val_loss: 1.1010 - val_accuracy: 0.6308
# Epoch 34/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0265 - accuracy: 0.9932 - val_loss: 1.1310 - val_accuracy: 0.6256
# Epoch 35/250
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0380 - accuracy: 0.9915 - val_loss: 1.0689 - val_accuracy: 0.6615
# Epoch 36/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0317 - accuracy: 0.9932 - val_loss: 0.9192 - val_accuracy: 0.6923
# Epoch 37/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0276 - accuracy: 0.9949 - val_loss: 0.9072 - val_accuracy: 0.7077
# Epoch 38/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0267 - accuracy: 0.9966 - val_loss: 0.9163 - val_accuracy: 0.7026
# Epoch 39/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0268 - accuracy: 0.9932 - val_loss: 0.8637 - val_accuracy: 0.6974
# Epoch 40/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0217 - accuracy: 0.9966 - val_loss: 0.9079 - val_accuracy: 0.6974
# Epoch 41/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0205 - accuracy: 0.9949 - val_loss: 0.9078 - val_accuracy: 0.6974
# Epoch 42/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0259 - accuracy: 0.9949 - val_loss: 0.9031 - val_accuracy: 0.6923
# Epoch 43/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.9240 - val_accuracy: 0.6974
# Epoch 44/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0234 - accuracy: 0.9949 - val_loss: 0.8667 - val_accuracy: 0.7128
# Epoch 45/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.9444 - val_accuracy: 0.7077
# Epoch 46/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.7179
# Epoch 47/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0137 - accuracy: 0.9983 - val_loss: 1.0274 - val_accuracy: 0.7128
# Epoch 48/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0128 - accuracy: 0.9983 - val_loss: 1.0394 - val_accuracy: 0.7179
# Epoch 49/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0198 - accuracy: 0.9949 - val_loss: 0.9836 - val_accuracy: 0.7077
# Epoch 50/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0124 - accuracy: 0.9983 - val_loss: 1.0258 - val_accuracy: 0.7231
# Epoch 51/250
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0176 - accuracy: 0.9966 - val_loss: 1.0162 - val_accuracy: 0.7179
# Epoch 52/250
# 19/19 [==============================] - 1s 48ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.0513 - val_accuracy: 0.7077
# Epoch 53/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 1.0487 - val_accuracy: 0.7128
# Epoch 54/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0168 - accuracy: 0.9966 - val_loss: 1.0684 - val_accuracy: 0.7128
# Epoch 55/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0101 - accuracy: 0.9983 - val_loss: 1.0429 - val_accuracy: 0.7026
# Epoch 56/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.0461 - val_accuracy: 0.7026
# Epoch 57/250
# 19/19 [==============================] - 1s 48ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.0432 - val_accuracy: 0.7026
# Epoch 58/250
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0118 - accuracy: 0.9983 - val_loss: 1.1391 - val_accuracy: 0.7128
# Epoch 59/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.0447 - val_accuracy: 0.7077
# Epoch 60/250
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0135 - accuracy: 0.9983 - val_loss: 1.0844 - val_accuracy: 0.7128
# Epoch 61/250
# 19/19 [==============================] - 1s 49ms/step - loss: 0.0097 - accuracy: 0.9983 - val_loss: 1.0538 - val_accuracy: 0.6974
# Epoch 62/250
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 1.1457 - val_accuracy: 0.7179
# Epoch 63/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0142 - accuracy: 0.9966 - val_loss: 1.1700 - val_accuracy: 0.7231
# Epoch 64/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0135 - accuracy: 0.9966 - val_loss: 1.0117 - val_accuracy: 0.7231
# Epoch 65/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0149 - accuracy: 0.9966 - val_loss: 1.0376 - val_accuracy: 0.7128
# Epoch 66/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.0241 - val_accuracy: 0.7231
# Epoch 67/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0144 - accuracy: 0.9966 - val_loss: 1.0966 - val_accuracy: 0.7282
# Epoch 68/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 1.0886 - val_accuracy: 0.7333
# Epoch 69/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0086 - accuracy: 0.9983 - val_loss: 1.0650 - val_accuracy: 0.7179
# Epoch 70/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.1115 - val_accuracy: 0.7231
# Epoch 71/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0119 - accuracy: 0.9983 - val_loss: 1.1229 - val_accuracy: 0.7128
# Epoch 72/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 1.1337 - val_accuracy: 0.7026
# Epoch 73/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 1.1156 - val_accuracy: 0.7026
# Epoch 74/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.1250 - val_accuracy: 0.7077
# Epoch 75/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.1199 - val_accuracy: 0.7282
# Epoch 76/250
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 1.0967 - val_accuracy: 0.7128
# Epoch 77/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 1.1078 - val_accuracy: 0.6974
# Epoch 78/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1472 - val_accuracy: 0.7026
# Epoch 79/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 1.2304 - val_accuracy: 0.6872
# Epoch 80/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 1.2105 - val_accuracy: 0.7077
# Epoch 81/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 1.1201 - val_accuracy: 0.7128
# Epoch 82/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 1.0706 - val_accuracy: 0.7231
# Epoch 83/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.2666 - val_accuracy: 0.7282
# Epoch 84/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 1.1129 - val_accuracy: 0.7231
# Epoch 85/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0097 - accuracy: 0.9983 - val_loss: 1.0787 - val_accuracy: 0.7128
# Epoch 86/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.1244 - val_accuracy: 0.7077
# Epoch 87/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1540 - val_accuracy: 0.7282
# Epoch 88/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.1686 - val_accuracy: 0.7282
# Epoch 89/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0084 - accuracy: 0.9983 - val_loss: 1.1297 - val_accuracy: 0.7179
# Epoch 90/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2176 - val_accuracy: 0.7282
# Epoch 91/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 1.1493 - val_accuracy: 0.7231
# Epoch 92/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.1349 - val_accuracy: 0.7231
# Epoch 93/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.2130 - val_accuracy: 0.7231
# Epoch 94/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.2251 - val_accuracy: 0.7231
# Epoch 95/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.3161 - val_accuracy: 0.7026
# Epoch 96/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.3200 - val_accuracy: 0.6974
# Epoch 97/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.3239 - val_accuracy: 0.7026
# Epoch 98/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2554 - val_accuracy: 0.7179
# Epoch 99/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.2483 - val_accuracy: 0.7179
# Epoch 100/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2784 - val_accuracy: 0.7231
# Epoch 101/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.2351 - val_accuracy: 0.7179
# Epoch 102/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.2111 - val_accuracy: 0.7026
# Epoch 103/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.2747 - val_accuracy: 0.7231
# Epoch 104/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2614 - val_accuracy: 0.7436
# Epoch 105/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0153 - accuracy: 0.9966 - val_loss: 1.2006 - val_accuracy: 0.7231
# Epoch 106/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.1805 - val_accuracy: 0.7179
# Epoch 107/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.2591 - val_accuracy: 0.7231
# Epoch 108/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0089 - accuracy: 0.9983 - val_loss: 1.3286 - val_accuracy: 0.7231
# Epoch 109/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.2437 - val_accuracy: 0.7179
# Epoch 110/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.2700 - val_accuracy: 0.7282
# Epoch 111/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2434 - val_accuracy: 0.7385
# Epoch 112/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.2566 - val_accuracy: 0.7333
# Epoch 113/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2838 - val_accuracy: 0.7231
# Epoch 114/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.2538 - val_accuracy: 0.7333
# Epoch 115/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 1.2198 - val_accuracy: 0.7333
# Epoch 116/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 1.2836 - val_accuracy: 0.7179
# Epoch 117/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 1.3273 - val_accuracy: 0.7231
# Epoch 118/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.3186 - val_accuracy: 0.7231
# Epoch 119/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.2029 - val_accuracy: 0.7179
# Epoch 120/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.2121 - val_accuracy: 0.7385
# Epoch 121/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.2194 - val_accuracy: 0.7179
# Epoch 122/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0148 - accuracy: 0.9966 - val_loss: 1.1420 - val_accuracy: 0.7179
# Epoch 123/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.2340 - val_accuracy: 0.7128
# Epoch 124/250
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0072 - accuracy: 0.9983 - val_loss: 1.2258 - val_accuracy: 0.7231
# Epoch 125/250
# 19/19 [==============================] - 1s 50ms/step - loss: 0.0068 - accuracy: 0.9966 - val_loss: 1.2573 - val_accuracy: 0.7385
# Epoch 126/250
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 1.1333 - val_accuracy: 0.7436
# Epoch 127/250
# 19/19 [==============================] - 1s 48ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.1617 - val_accuracy: 0.7333
# Epoch 128/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0156 - accuracy: 0.9966 - val_loss: 1.1954 - val_accuracy: 0.7179
# Epoch 129/250
# 19/19 [==============================] - 1s 50ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.3039 - val_accuracy: 0.7179
# Epoch 130/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0071 - accuracy: 0.9966 - val_loss: 1.2325 - val_accuracy: 0.7282
# Epoch 131/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0079 - accuracy: 0.9983 - val_loss: 1.2495 - val_accuracy: 0.7231
# Epoch 132/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2557 - val_accuracy: 0.7179
# Epoch 133/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.2866 - val_accuracy: 0.7231
# Epoch 134/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1
250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 1.2800 - val_accuracy: 0.7487
# Epoch 179/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 1.3809 - val_accuracy: 0.7436
# Epoch 180/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 1.2734 - val_accuracy: 0.7436
# Epoch 181/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.2939 - val_accuracy: 0.7128
# Epoch 182/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3815 - val_accuracy: 0.7128
# Epoch 183/250
# 19/19 [==============================] - 1s 42ms/step - loss: 7.0107e-04 - accuracy: 1.0000 - val_loss: 1.4124 - val_accuracy: 0.7231
# Epoch 184/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4431 - val_accuracy: 0.7333
# Epoch 185/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4960 - val_accuracy: 0.7231
# Epoch 186/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4307 - val_accuracy: 0.7231
# Epoch 187/250
# 19/19 [==============================] - 1s 42ms/step - loss: 8.6531e-04 - accuracy: 1.0000 - val_loss: 1.4170 - val_accuracy: 0.7026
# Epoch 188/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0033 - accuracy: 0.9966 - val_loss: 1.3741 - val_accuracy: 0.7179
# Epoch 189/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0106 - accuracy: 0.9983 - val_loss: 2.0751 - val_accuracy: 0.6821
# Epoch 190/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0087 - accuracy: 0.9966 - val_loss: 1.3444 - val_accuracy: 0.7538
# Epoch 191/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 1.3885 - val_accuracy: 0.7282
# Epoch 192/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.2417 - val_accuracy: 0.7282
# Epoch 193/250
# 19/19 [==============================] - 1s 70ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.2116 - val_accuracy: 0.7385
# Epoch 194/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2546 - val_accuracy: 0.7487
# Epoch 195/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2646 - val_accuracy: 0.7436
# Epoch 196/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4578 - val_accuracy: 0.7128
# Epoch 197/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.3571 - val_accuracy: 0.7333
# Epoch 198/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3337 - val_accuracy: 0.7333
# Epoch 199/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.4036 - val_accuracy: 0.7231
# Epoch 200/250
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0021 - accuracy: 0.9983 - val_loss: 1.4525 - val_accuracy: 0.7179
# Epoch 201/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0024 - accuracy: 0.9983 - val_loss: 1.5233 - val_accuracy: 0.7231
# Epoch 202/250
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0021 - accuracy: 0.9983 - val_loss: 1.5526 - val_accuracy: 0.7487
# Epoch 203/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0035 - accuracy: 0.9983 - val_loss: 1.3778 - val_accuracy: 0.7538
# Epoch 204/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3796 - val_accuracy: 0.7590
# Epoch 205/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.3210 - val_accuracy: 0.7282
# Epoch 206/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.4458 - val_accuracy: 0.7487
# Epoch 207/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5569 - val_accuracy: 0.7538
# Epoch 208/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5539 - val_accuracy: 0.7436
# Epoch 209/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 1.9810 - val_accuracy: 0.7436
# Epoch 210/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.9585 - val_accuracy: 0.7385
# Epoch 211/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.7482 - val_accuracy: 0.7333
# Epoch 212/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0031 - accuracy: 0.9983 - val_loss: 1.7051 - val_accuracy: 0.7436
# Epoch 213/250
# 19/19 [==============================] - 1s 46ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 1.5289 - val_accuracy: 0.7179
# Epoch 214/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5995 - val_accuracy: 0.7333
# Epoch 215/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 1.8712 - val_accuracy: 0.7436
# Epoch 216/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0101 - accuracy: 0.9983 - val_loss: 1.5767 - val_accuracy: 0.7333
# Epoch 217/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.5751 - val_accuracy: 0.7026
# Epoch 218/250
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.7285 - val_accuracy: 0.7282
# Epoch 219/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.7859 - val_accuracy: 0.7026
# Epoch 220/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.6845 - val_accuracy: 0.7487
# Epoch 221/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 1.5143 - val_accuracy: 0.7026
# Epoch 222/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.6317 - val_accuracy: 0.7436
# Epoch 223/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.6228 - val_accuracy: 0.7436
# Epoch 224/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 1.8209 - val_accuracy: 0.7385
# Epoch 225/250
# 19/19 [==============================] - 1s 42ms/step - loss: 9.8182e-04 - accuracy: 1.0000 - val_loss: 1.4670 - val_accuracy: 0.7231
# Epoch 226/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 1.5025 - val_accuracy: 0.7077
# Epoch 227/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 1.7368 - val_accuracy: 0.7026
# Epoch 228/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.4480 - val_accuracy: 0.7077
# Epoch 229/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 1.5202 - val_accuracy: 0.7077
# Epoch 230/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.6464 - val_accuracy: 0.7077
# Epoch 231/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.5251 - val_accuracy: 0.6974
# Epoch 232/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 1.7462 - val_accuracy: 0.7026
# Epoch 233/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0132 - accuracy: 0.9983 - val_loss: 1.5846 - val_accuracy: 0.6974
# Epoch 234/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0227 - accuracy: 0.9932 - val_loss: 1.7779 - val_accuracy: 0.7385
# Epoch 235/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0210 - accuracy: 0.9915 - val_loss: 1.9833 - val_accuracy: 0.6923
# Epoch 236/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0185 - accuracy: 0.9915 - val_loss: 1.8107 - val_accuracy: 0.7128
# Epoch 237/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0201 - accuracy: 0.9949 - val_loss: 2.2357 - val_accuracy: 0.6872
# Epoch 238/250
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 2.2700 - val_accuracy: 0.7128
# Epoch 239/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 1.7482 - val_accuracy: 0.7385
# Epoch 240/250
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 2.0161 - val_accuracy: 0.6974
# Epoch 241/250
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0413 - accuracy: 0.9949 - val_loss: 1.8124 - val_accuracy: 0.7231
# Epoch 242/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0079 - accuracy: 0.9966 - val_loss: 1.7101 - val_accuracy: 0.7538
# Epoch 243/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 1.5652 - val_accuracy: 0.7179
# Epoch 244/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0198 - accuracy: 0.9983 - val_loss: 1.8274 - val_accuracy: 0.7436
# Epoch 245/250
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0413 - accuracy: 0.9949 - val_loss: 1.5996 - val_accuracy: 0.7026
# Epoch 246/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.7968 - val_accuracy: 0.6974
# Epoch 247/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0124 - accuracy: 0.9949 - val_loss: 2.2311 - val_accuracy: 0.7231
# Epoch 248/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0114 - accuracy: 0.9983 - val_loss: 1.9565 - val_accuracy: 0.6872
# Epoch 249/250
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 1.7449 - val_accuracy: 0.6923
# Epoch 250/250
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0228 - accuracy: 0.9880 - val_loss: 2.2047 - val_accuracy: 0.7282

# %%
# visualise training history
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0,1)
plt.legend(['train', 'test'], loc="lower right")
plt.show()

# %% [markdown]
# Same overfitting pattern exhibited by the CNN architecture and parameters I used.

# %% [markdown]
# c. Check the performance of your model

# %%
train_loss, train_accuracy = model.evaluate(train_X, train_y, verbose=0)
test_loss, test_accuracy = model.evaluate(test_X, test_y, verbose=0)

print(f"Train accuracy: {train_accuracy * 100:.2f}%")
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Train accuracy: 100.00%
# Test accuracy: 72.82%

# %% [markdown]
# d. Create a confusion matrix to inspect the model's output

# %%
predictions = model.predict(test_X)

predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_y, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(10, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='g',
    xticklabels=['Malignant', 'Benign', 'Normal'],
    yticklabels=['Malignant', 'Benign', 'Normal']
)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('CNN Confusion Matrix')
plt.show()
# Out:
# 7/7 [==============================] - 0s 11ms/step

# %% [markdown]
# ### Optional Exercise
# Both models for multiclassification overfit. This can be caused by the high complexity of the networks that we have used, it could also be due to the low number of training examples we have (around 600 used for training+ an imbalanced dataset).
#
# Refer to this data augmentation technique suggested by Keras [Image Data Generator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator), and check whether it can help bridge the gap between the accuracy in training and the accuracy of the test set.

# %%
#This part is optional
#Try data augmentation to reduce overfitting, or add dropout layers to your neural network

# %% [markdown]
# ### Regular Level
# In this part, we wish to implement our own deep learning network for binary classification.
# ### Exercise 13
# To test the functions, let's use a network of the dimensions [64 x 64, 128,64,1]
#
# We'll first write the function initialize(network_dims), which will initialize the weights and biases of our network.

# %% [markdown]
# a. Copy your **y** vector of binary classification (not the one hot-encoded matrix)

# %%
y = binary_labels(labels)
print(y.shape)
# Out:
# 100%|██████████| 780/780 [00:00<?, ?it/s]
# (780,)

# %%
train_X, test_X, train_y, test_y = train_test_split(np_images_flattened, y, test_size=ts, shuffle=True, random_state=rs)

# %%
def initialize(network_dims):
    params = {}
    L = len(network_dims)
    for l in range(1, L):
        params['W' + str(l)] = np.random.randn(network_dims[l], network_dims[l - 1])
        params['b' + str(l)] = np.random.randn(network_dims[l], 1)

    return params

# %%
params=initialize([train_X.shape[1], 128,64, 1])

# %%
print('shape of W1', params['W1'].shape)
print('shape of b1', params['b1'].shape)
print('shape of W2', params['W2'].shape)
print('shape of b2', params['b2'].shape)
print('shape of W3', params['W3'].shape)
print('shape of b3', params['b3'].shape)
# Out:
# shape of W1 (128, 4096)
# shape of b1 (128, 1)
# shape of W2 (64, 128)
# shape of b2 (64, 1)
# shape of W3 (1, 64)
# shape of b3 (1, 1)

# %% [markdown]
# You are now requested to implement the forward_pass(X, params), which takes your training set X as input and returns the activations of the hidden and final layer.
# Your function should implement the following functions:
#
# $$Z^{[l]}=W^{[l]}.A^{[l-1]}+b^{[l]}$$
# $$A^{[l]}=\sigma Z^{[l]}$$
#
# You of course need to iterate over the layers of your model (hidden and final/output layer).

# %%
def forward_pass(X, params):
    activations = {'A0': X}
    A = X

    L = len(params) // 2

    for l in range(1, L + 1):
        W = params['W' + str(l)]
        b = params['b' + str(l)]

        Z = np.dot(W, A) + b
        A = 1 / (1 + np.exp(-Z))

        activations['A' + str(l)] = A

    return activations

# %%
#recall that X in our scenario is of shape (nf, ne)
train_X=train_X.T

# %%
activations=forward_pass(train_X, params)

# %%
print("The shape of the activation of the first layer",activations['A1'].shape)
print("The shape of the activation of the second layer",activations['A2'].shape)
print("The shape of the activation of the output layer",activations['A3'].shape)
# Out:
# The shape of the activation of the first layer (128, 585)
# The shape of the activation of the second layer (64, 585)
# The shape of the activation of the output layer (1, 585)

# %% [markdown]
# ### Exercise 14
# We get now to implementing our gradient descent.
#
# Write a function gradient_descent(params, activations, y, lr), which input your parameters, the activations of your forward_pass, your ground truth vector y and your learning_rate lr.
#
# The function needs to implement the following equations:
#
# $$dZ^{[fl]}=A^{[fl]}-y$$
# $$dZ^{[l-1]}=W^{[l]}T .dZ^{[l]} * A^{[l-1]}(1-A^{[l-1]})$$
# $$dW^{[l]}=\frac {1}{ne} (dZ^{[l]}.A^{[l-1]}T)$$
# $$dW^{[l]}=\frac {1}{ne} \sum dZ^{[l]} $$
# $$W=W-\alpha dW$$
#
# $$W=b-\alpha db$$

# %%
def gradient_descent(activations, params, y, lr):
    L = len(params) // 2
    ne = activations['A0'].shape[1]

    grads = {}

    #Calculate all gradients first
    for l in range(L, 0, -1):
        A_prev = activations['A' + str(l - 1)]
        A = activations['A' + str(l)]

        if l == L:
            dZ = A - y
        else:
            W_next = params['W' + str(l + 1)]
            dZ = np.dot(W_next.T, dZ) * A * (1 - A)

        grads['W' + str(l)] = (1 / ne) * np.dot(dZ, A_prev.T)
        grads['b' + str(l)] = (1 / ne) * np.sum(dZ, axis=1, keepdims=True)

    #Update all parameters
    for l in range(1, L + 1):
        params['W' + str(l)] -= lr * grads['W' + str(l)]
        params['b' + str(l)] -= lr * grads['b' + str(l)]

    return params

# %%
params=gradient_descent(activations, params, train_y, lr=0.5)

# %%
print('shape of W1', params['W1'].shape)
print('shape of b1', params['b1'].shape)
print('shape of W2', params['W2'].shape)
print('shape of b2', params['b2'].shape)
print('shape of W3', params['W3'].shape)
print('shape of b3', params['b3'].shape)
# Out:
# shape of W1 (128, 4096)
# shape of b1 (128, 1)
# shape of W2 (64, 128)
# shape of b2 (64, 1)
# shape of W3 (1, 64)
# shape of b3 (1, 1)

# %% [markdown]
# ### Exercise 15
# Now we can implement our dnn model in 3 simple steps
# 1. initialize the matrices W and the bias vectors b
# 2. repeat until number of iterations is reached
#     2.1. get your matrices of activations
#     2.2. update the weights W and biases b using gradient descent
# 3. return the final matrices for  W and bias vectors b
#
# dnn(X, y, network_dims, lr, iters), takes the matrix X as an input, the vector of true labels y, network dimensions, a learning rate, and the number of iterations iters. The function returns the learned parameters of the model, namely W and b.

# %%
def dnn(X, y, network_dims, lr, iters):
    params = initialize(network_dims)
    
    for i in tqdm(range(iters)):
        activations = forward_pass(X, params)
        params = gradient_descent(activations, params, y, lr)
    
    return params

# %%
params=dnn(train_X, train_y, network_dims = [train_X.shape[0], 64, 32,1 ], lr = 0.75, iters = 50)
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 97.37it/s]

# %%
def predict(X, params):
    activations = forward_pass(X, params)
    L = len(params) // 2
    Af = activations['A' + str(L)]
    return  1*(Af>=0.5)

# %%
predictions=predict(test_X.T, params)

# %%
print("Accuracy on our test set is", accuracy_score(test_y.flatten(), predictions.flatten())*100, "%")
# Out:
# Accuracy on our test set is 76.92307692307693 %

# %% [markdown]
# #### Quite a good result actually.

# %% [markdown]
# ## Advanced Level
# We said in the lecture that a sigmoid activated neurone predicts values between 0 and 1, making it adequate for binary classification.
#
# We also said that a softmax activation function is suitable for multiclassification.
# To change our code above and make it capable of doing multiclassification, we need to implement the softmax function.
# We also said that the log_loss isn't useful in this case, we will instead use cross entropy loss.
#
# We also said that **dZL** (L for final layer) remains the same as before.
#
# Your task is to modify the code you implemented above to handle the same multiclassification problem you handled with Keras.
#
# We are not interested in a completely new implementation, we expect that you will modify one of your functions above and adapt the code to handle the new type of classification (multiclass).

# %%
def softmax(Z):
    exp_Z = np.exp(Z - np.max(Z, axis=0, keepdims=True))
    return exp_Z / np.sum(exp_Z, axis=0, keepdims=True)


def forward_pass_multiclassification(X, params):
    activations = {'A0': X}
    A = X

    L = len(params) // 2

    for l in range(1, L + 1):
        W = params['W' + str(l)]
        b = params['b' + str(l)]

        Z = np.dot(W, A) + b

        if l == L:
            #Final layer: softmax for multiclass classification
            A = softmax(Z)
        else:
            #Hidden layers: sigmoid
            A = 1 / (1 + np.exp(-Z))

        activations['A' + str(l)] = A

    return activations

# %%
def dnn_2(X, y, network_dims, lr, iters):
    params = initialize(network_dims)

    for i in tqdm(range(iters)):
        activations = forward_pass_multiclassification(X, params)
        
        params = gradient_descent(activations, params, y, lr)
    return params

# %%
y = to_categorical(
    [0 if label == 'malignant' else 1 if label == 'benign' else 2 for label in labels],
    num_classes=3
)
train_X, test_X, train_y, test_y = train_test_split(np_images_flattened, y, test_size=ts, shuffle=True, random_state=rs)

# %%
params = dnn_2(train_X.T, train_y.T, network_dims=[train_X.shape[1], 64, 4, 3], lr=0.005, iters=500)
# Out:
# 100%|██████████| 500/500 [00:04<00:00, 107.42it/s]

# %%
def predict(X, params):
    activations = forward_pass_multiclassification(X, params)
    C = len(params) // 2
    Af = activations['A' + str(C)]
    return np.argmax(Af, axis=0)

# %%
predictions=predict(test_X.T, params)

# %%
true_labels = np.argmax(test_y, axis=1)

print("Accuracy on our test set is", accuracy_score(true_labels, predictions) * 100, "%")
# Out:
# Accuracy on our test set is 57.43589743589743 %

# %% [markdown]
# The performance isn't as strong as the Keras models.
#
# In the advanced CV lecture, you'll explore transfer learning, a technique that enables us to repurpose a pre-trained model for classifying different objects and adapt it to identify cancer scans. This method is especially beneficial when the training dataset is limited, and will allow us to improve the accuracy of our cancer detection model.

# %% [markdown]
# #### Hope you enjoyed working with DNNs and CNNs
